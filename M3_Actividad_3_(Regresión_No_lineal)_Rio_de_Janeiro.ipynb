# %%
#librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice y eliminar filas innecesarias
Rio_de_Janeiro = pd.read_csv("Listings Final-Rio de Janeiro.csv")

# %%
#Identificar valores nulos por columna
Valores_Nulos= Rio_de_Janeiro.isnull().sum()
Columnas_Con_Nulos = Valores_Nulos[Valores_Nulos > 0]
Columnas_Con_Nulos
# Out:
# description                      1163
# neighborhood_overview           17648
# host_location                    6795
# host_about                      18113
# host_response_time               5785
# host_response_rate               5785
# host_acceptance_rate             3575
# host_is_superhost                 868
# host_neighbourhood               5885
# neighbourhood                   17648
# neighbourhood_group_cleansed    34664
# bathrooms                         840
# bathrooms_text                     41
# bedrooms                          138
# beds                              842
# price                             972
# calendar_updated                34664
# has_availability                  337
# first_review                     8446
# last_review                      8446
# review_scores_rating             8446
# review_scores_accuracy           8455
# review_scores_cleanliness        8455
# review_scores_checkin            8455
# review_scores_communication      8455
# review_scores_location           8455
# review_scores_value              8457
# license                         34664
# reviews_per_month                8446
# dtype: int64

# %%
#Información tipos de columnas
Tipos_Columnas = Rio_de_Janeiro[Columnas_Con_Nulos.index].dtypes
Columnas_Object = Tipos_Columnas[Tipos_Columnas == 'object']
Columnas_Object
# Out:
# description              object
# neighborhood_overview    object
# host_location            object
# host_about               object
# host_response_time       object
# host_response_rate       object
# host_acceptance_rate     object
# host_is_superhost        object
# host_neighbourhood       object
# neighbourhood            object
# bathrooms_text           object
# price                    object
# has_availability         object
# first_review             object
# last_review              object
# dtype: object

# %%
#Información tipos de columnas
Tipos_Columnas = Rio_de_Janeiro[Columnas_Con_Nulos.index].dtypes
Columnas_Object = Tipos_Columnas[Tipos_Columnas == 'float']
Columnas_Object
# Out:
# neighbourhood_group_cleansed    float64
# bathrooms                       float64
# bedrooms                        float64
# beds                            float64
# calendar_updated                float64
# review_scores_rating            float64
# review_scores_accuracy          float64
# review_scores_cleanliness       float64
# review_scores_checkin           float64
# review_scores_communication     float64
# review_scores_location          float64
# review_scores_value             float64
# license                         float64
# reviews_per_month               float64
# dtype: object

# %%
#Realizamos una copia del dataframe
copia_Rio_de_Janeiro = Rio_de_Janeiro.copy()

# %%
#Convertir la variable price a numerico
copia_Rio_de_Janeiro['price'] = copia_Rio_de_Janeiro['price'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\571970272.py:2: SyntaxWarning: invalid escape sequence '\$'
#   copia_Rio_de_Janeiro['price'] = copia_Rio_de_Janeiro['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
#Eliminamos esta columna ya que todos los datos son nulos
copia_Rio_de_Janeiro= copia_Rio_de_Janeiro.drop(columns=['neighbourhood_group_cleansed'])
copia_Rio_de_Janeiro= copia_Rio_de_Janeiro.drop(columns=['license'])
copia_Rio_de_Janeiro= copia_Rio_de_Janeiro.drop(columns=['calendar_updated'])

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto
copia_Rio_de_Janeiro["description"] = copia_Rio_de_Janeiro["description"].fillna("DESCRIPCIÓN FALTANTE")
copia_Rio_de_Janeiro["neighborhood_overview"] = copia_Rio_de_Janeiro["neighborhood_overview"].fillna("SIN INFORMACIÓN")
copia_Rio_de_Janeiro["host_location"] = copia_Rio_de_Janeiro["host_location"].fillna("SIN INFORMACIÓN")
copia_Rio_de_Janeiro["host_about"] = copia_Rio_de_Janeiro["host_about"].fillna("SIN INFORMACIÓN")
copia_Rio_de_Janeiro["host_response_time"] = copia_Rio_de_Janeiro["host_response_time"].fillna("SIN INFORMACIÓN")
copia_Rio_de_Janeiro["host_response_rate"] = copia_Rio_de_Janeiro["host_response_rate"].fillna("SIN INFORMACIÓN")
copia_Rio_de_Janeiro["host_acceptance_rate"] = copia_Rio_de_Janeiro["host_acceptance_rate"].fillna("SIN INFORMACIÓN")
copia_Rio_de_Janeiro["host_is_superhost"] = copia_Rio_de_Janeiro["host_is_superhost"].fillna("VALIDACIÓN PENDIENTE")
copia_Rio_de_Janeiro["host_neighbourhood"] = copia_Rio_de_Janeiro["host_neighbourhood"].fillna("SIN INFORMACIÓN")
copia_Rio_de_Janeiro["neighbourhood"] = copia_Rio_de_Janeiro["neighbourhood"].fillna("SIN INFORMACIÓN")
copia_Rio_de_Janeiro["bathrooms_text"] = copia_Rio_de_Janeiro["bathrooms_text"].fillna("INFORMACIÓN FALTANTE")
copia_Rio_de_Janeiro["has_availability"] = copia_Rio_de_Janeiro["has_availability"].fillna("INFORMACIÓN NO DISPONIBLE")
copia_Rio_de_Janeiro["first_review"] = copia_Rio_de_Janeiro["first_review"].fillna("SIN RESEÑA")
copia_Rio_de_Janeiro["last_review"] = copia_Rio_de_Janeiro["last_review"].fillna("SIN RESEÑA")

# %%
#Sustituir valores nulos con promedio o media
copia_Rio_de_Janeiro["review_scores_accuracy"] = copia_Rio_de_Janeiro["review_scores_accuracy"].fillna(round(copia_Rio_de_Janeiro["review_scores_accuracy"].mean(), 1))
copia_Rio_de_Janeiro["review_scores_cleanliness"] = copia_Rio_de_Janeiro["review_scores_cleanliness"].fillna(round(copia_Rio_de_Janeiro["review_scores_cleanliness"].mean(), 1))
copia_Rio_de_Janeiro["review_scores_checkin"] = copia_Rio_de_Janeiro["review_scores_checkin"].fillna(round(copia_Rio_de_Janeiro["review_scores_checkin"].mean(), 1))
copia_Rio_de_Janeiro["price"] = copia_Rio_de_Janeiro ["price"].fillna(round(copia_Rio_de_Janeiro["price"].mean(), 1))
copia_Rio_de_Janeiro["review_scores_communication"] = copia_Rio_de_Janeiro["review_scores_communication"].fillna(round(copia_Rio_de_Janeiro["review_scores_communication"].mean(), 1))
copia_Rio_de_Janeiro["review_scores_location"] = copia_Rio_de_Janeiro["review_scores_location"].fillna(round(copia_Rio_de_Janeiro["review_scores_location"].mean(), 1))
copia_Rio_de_Janeiro["review_scores_value"] = copia_Rio_de_Janeiro["review_scores_value"].fillna(round(copia_Rio_de_Janeiro["review_scores_value"].mean(), 1))
copia_Rio_de_Janeiro["review_scores_rating"] = copia_Rio_de_Janeiro["review_scores_rating"].fillna(round(copia_Rio_de_Janeiro["review_scores_rating"].mean(), 1))
copia_Rio_de_Janeiro["reviews_per_month"] = copia_Rio_de_Janeiro["reviews_per_month"].fillna(round(copia_Rio_de_Janeiro["reviews_per_month"].mean(), 1))

# %%
#Sustituir valores nulos por un valor numérico en  concreto
copia_Rio_de_Janeiro["beds"]=copia_Rio_de_Janeiro["beds"].fillna("-")
copia_Rio_de_Janeiro["bedrooms"]=copia_Rio_de_Janeiro["bedrooms"].fillna("-")
copia_Rio_de_Janeiro["bathrooms"]=copia_Rio_de_Janeiro["bathrooms"].fillna("-")

# %%
#Corroboramos valores nulos
# Ajustar maximo de filas
pd.options.display.max_rows = None
valores_nulos=copia_Rio_de_Janeiro.isnull().sum()
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
# name                                            0
# description                                     0
# neighborhood_overview                           0
# picture_url                                     0
# host_id                                         0
# host_url                                        0
# host_name                                       0
# host_since                                      0
# host_location                                   0
# host_about                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_is_superhost                               0
# host_thumbnail_url                              0
# host_picture_url                                0
# host_neighbourhood                              0
# host_listings_count                             0
# host_total_listings_count                       0
# host_verifications                              0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood                                   0
# neighbourhood_cleansed                          0
# latitude                                        0
# longitude                                       0
# property_type                                   0
# room_type                                       0
# accommodates                                    0
# bathrooms                                       0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# amenities                                       0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# has_availability                                0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# calendar_last_scraped                           0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# first_review                                    0
# last_review                                     0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# instant_bookable                                0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# dtype: int64

# %%
#Seleccionar variables relevantes
Rio_de_janeiro_variables = copia_Rio_de_Janeiro[['host_response_rate', 'host_acceptance_rate', 'host_total_listings_count', 'accommodates', 'reviews_per_month', 'price']]

# %%
#ELIMINAR OUTLIERS POR EL METODO DE DESVIACION ESTANDAR
#Separar por columnas cualitativas y cuantitativas
columnas_cualitativas = Rio_de_janeiro_variables.select_dtypes(include = 'object')
columnas_cuantitativas = Rio_de_janeiro_variables.select_dtypes(include = ['int64', 'float64'])

# %%
#Hacer un boxplot de valores atipicos de las columnas cuantitativas
fig = plt.figure(figsize = (20, 10))
columnas_cuantitativas.plot(kind = 'box', vert = False)
plt.title("Valores atipicos")
plt.show()

# %%
#Identificar los limites superior e inferior
y = columnas_cuantitativas
Limite_superior = y.mean() + 3*y.std()
Limite_inferior = y.mean() - 3*y.std()
print("Limite superior permitido", Limite_superior)
print("Limite inferior permitido", Limite_inferior)
# Out:
# Limite superior permitido host_total_listings_count      482.579203
# accommodates                    11.026495
# reviews_per_month                4.208422
# price                        17492.868351
# dtype: float64
# Limite inferior permitido host_total_listings_count     -423.898208
# accommodates                    -2.996839
# reviews_per_month               -2.028960
# price                       -16030.491222
# dtype: float64

# %%
#Filtrar solo por columnas dentro de los limites
columnas_cuantitativas_sin_outliers = columnas_cuantitativas[(y <= Limite_superior) & (y >= Limite_inferior)]

# %%
#Revisar valores nulos
valores_nulos_cuantitativo = columnas_cuantitativas_sin_outliers.isnull().sum()
valores_nulos_cuantitativo
# Out:
# host_total_listings_count    446
# accommodates                 644
# reviews_per_month            650
# price                         93
# dtype: int64

# %%
#Hacer una copia del dataframe y rellenar los valores nulos con la media
columnas_cuantitativas_limpio = columnas_cuantitativas_sin_outliers.copy()
columnas_cuantitativas_limpio = columnas_cuantitativas_limpio.fillna(round(columnas_cuantitativas_sin_outliers.mean(), 1))

# %%
#Se juntan las columnas cualitativas con las cuantitativas
Rio_de_janeiro_outliers = pd.concat([columnas_cuantitativas_limpio, columnas_cualitativas], axis = 1)
Rio_de_janeiro_outliers.head()
# Out:
#    host_total_listings_count  accommodates  reviews_per_month  price  \
# 0                        5.0           5.0               1.88  310.0
# 1                        5.0           3.0               1.70  203.0
# 2                        3.0           2.0               0.03  220.0
# 3                        2.0           2.0               2.85  201.0
# 4                        8.0           2.0               3.04  321.0
#
#   host_response_rate host_acceptance_rate
# 0               100%                 100%
# 1               100%                  82%
# 2               100%                  47%
# 3               100%                  98%
# 4               100%                 100%

# %%
#Comprobamos que no existan valores nulos
valores_nulos_Rio_de_janeiro_outliers = Rio_de_janeiro_outliers.isnull().sum()
valores_nulos_Rio_de_janeiro_outliers
# Out:
# host_total_listings_count    0
# accommodates                 0
# reviews_per_month            0
# price                        0
# host_response_rate           0
# host_acceptance_rate         0
# dtype: int64

# %%
#Convertir archivo filtrado a CSV
#Rio_de_janeiro_outliers.to_csv('Rio de Janeiro sin outliers.csv')

# %%
#Descargar archivo en csv
#from google.colab import files
#files.download("Rio de Janeiro sin outliers.csv")

# %% [markdown]
# Usamos las siguientes ecuaciones como funciones de ajuste.
#
#         y = ax^2 + bx + c   ("Función cuadrática") Es útil cuando los datos muestran una tendencia de crecimiento o decrecimiento que no es constante, con una curva simétrica.
#
#         y = a*exp(bx) + c   ("Función exponencial") La función exponencial modela relaciones donde el crecimiento o decrecimiento es rápido al principio y luego se estabiliza.
#
#         y = 1/a*x           ("Función inversa") Esta función modela relaciones inversamente proporcionales. A medida que x aumenta, y decrece de forma proporcional.
#
#         y = a*np.sin(x) + b ("Función senoidal") Esta función modela relaciones periódicas. Es útil cuando los datos tienen una naturaleza cíclica o estacional.
#
#         y = a*np.tan(x) + b ("Función tangencial") La función tangencial tiene un crecimiento asintótico y se usa cuando los datos tienen una curva muy pronunciada.
#
#         y = a*np.abs(x) + b*x + c (Función Valor absoluto) Esta función es útil para modelar relaciones donde el valor de y es sensible al valor absoluto de x, y tiene una pendiente lineal, con un cambio brusco en el valor de x.
#
#         y = (a*x**2 + b)/ c*x (Función cociente entre polinomios) Este tipo de función se usa cuando hay una relación racional entre las variables. Los cocientes de polinomios pueden captar relaciones no lineales que no son simétricas.
#
#         y = a*np.log(x) + b  (Función logaritmica)  La función logarítmica modela relaciones donde el crecimiento inicial es rápido y luego se desacelera. Es útil para relaciones de decrecimiento rápido.
#
#         y = a*x + b*x + c*x (Función lineal con producto de coeficientes) Esta función es una variante de una relación lineal con coeficientes multiplicativos.
#
#         y = 1/a*x**2  (Función cuadrática inversa) Esta función modela relaciones inversamente proporcionales al cuadrado de x, donde y disminuye rápidamente a medida que x aumenta.
#
#         y = a/b*x**2 + c*x (Función polinomial inversa) Una función inversa de este tipo puede modelar relaciones no lineales complejas entre variables, donde y tiene una curva de crecimiento o decrecimiento con respecto a x.

# %%
#Información tipos de columnas
columns_to_check = ['host_response_rate', 'host_acceptance_rate', 'host_total_listings_count', 'accommodates', 'reviews_per_month', 'price']
Rio_de_janeiro_outliers[columns_to_check].dtypes
# Out:
# host_response_rate            object
# host_acceptance_rate          object
# host_total_listings_count    float64
# accommodates                 float64
# reviews_per_month            float64
# price                        float64
# dtype: object

# %%
# Convertir 'host_response_rate' de string a float
Rio_de_janeiro_outliers['host_response_rate'] = Rio_de_janeiro_outliers['host_response_rate'].replace('[\%,]', '', regex=True).replace('SIN INFORMACIÓN', '0', regex=True).astype(float)

# Convertir 'host_acceptance_rate' de string a float
Rio_de_janeiro_outliers['host_acceptance_rate'] = Rio_de_janeiro_outliers['host_acceptance_rate'].replace('[\%,]', '', regex=True).replace('SIN INFORMACIÓN', '0', regex=True).astype(float)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\%'
# <>:5: SyntaxWarning: invalid escape sequence '\%'
# <>:2: SyntaxWarning: invalid escape sequence '\%'
# <>:5: SyntaxWarning: invalid escape sequence '\%'
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2402634992.py:2: SyntaxWarning: invalid escape sequence '\%'
#   Rio_de_janeiro_outliers['host_response_rate'] = Rio_de_janeiro_outliers['host_response_rate'].replace('[\%,]', '', regex=True).replace('SIN INFORMACIÓN', '0', regex=True).astype(float)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2402634992.py:5: SyntaxWarning: invalid escape sequence '\%'
#   Rio_de_janeiro_outliers['host_acceptance_rate'] = Rio_de_janeiro_outliers['host_acceptance_rate'].replace('[\%,]', '', regex=True).replace('SIN INFORMACIÓN', '0', regex=True).astype(float)

# %%
#Información tipos de columnas
columns_to_check = ['host_response_rate', 'host_acceptance_rate', 'host_total_listings_count', 'accommodates', 'reviews_per_month', 'price']
Rio_de_janeiro_outliers[columns_to_check].dtypes
# Out:
# host_response_rate           float64
# host_acceptance_rate         float64
# host_total_listings_count    float64
# accommodates                 float64
# reviews_per_month            float64
# price                        float64
# dtype: object

# %%
import scipy.special as special
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

import numpy as np # Import the NumPy library and alias it as 'np'
from sklearn.metrics import r2_score

# %%
# Lista de pares de variables
variables = [
    ('host_response_rate', 'host_acceptance_rate'),
    ('host_response_rate', 'host_total_listings_count'),
    ('host_response_rate', 'accommodates'),
    ('host_response_rate', 'reviews_per_month'),
    ('host_response_rate', 'price'),
    ('host_acceptance_rate', 'host_total_listings_count'),
    ('host_acceptance_rate', 'accommodates'),
    ('host_acceptance_rate', 'reviews_per_month'),
    ('host_acceptance_rate', 'price'),
    ('host_acceptance_rate', 'host_response_rate'),
    ('host_total_listings_count', 'accommodates'),
    ('host_total_listings_count', 'reviews_per_month'),
    ('host_total_listings_count', 'price'),
    ('host_total_listings_count', 'host_response_rate'),
    ('host_total_listings_count', 'host_acceptance_rate'),
    ('accommodates', 'reviews_per_month'),
    ('accommodates', 'price'),
    ('accommodates', 'host_response_rate'),
    ('accommodates', 'host_acceptance_rate'),
    ('accommodates', 'host_total_listings_count'),
    ('reviews_per_month', 'price'),
    ('reviews_per_month', 'host_response_rate'),
    ('reviews_per_month', 'host_acceptance_rate'),
    ('reviews_per_month', 'host_total_listings_count'),
    ('reviews_per_month', 'accommodates'),
]

# %% [markdown]
# **Regresión No Lineal - Función Cuadrática**

# %%
# Definir la función no lineal
def func1(x, a, b, c):
    return a * np.abs(x) + b * x + c

# Lista para almacenar los resultados
resultados = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros, covs = curve_fit(func1, x, y)
    a, b, c = parametros
    yfit = func1(x, a, b, c)

    # Calcular el coeficiente de determinación
    R2 = r2_score(y, yfit)

    # Almacenar los resultados en la lista
    resultados.append((var1, var2, a, b, c, R2))

# Crear un DataFrame a partir de los resultados
df_resultados = pd.DataFrame(resultados, columns=['Variable 1', 'Variable 2', 'a', 'b', 'c', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados = df_resultados.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados
# Out:
#                    Variable 1                 Variable 2           a  \
# 0          host_response_rate       host_acceptance_rate  100.294069
# 9        host_acceptance_rate         host_response_rate  100.350803
# 16               accommodates                      price -200.838547
# 22          reviews_per_month       host_acceptance_rate -108.857052
# 7        host_acceptance_rate          reviews_per_month  100.006602
# 21          reviews_per_month         host_response_rate -108.634985
# 3          host_response_rate          reviews_per_month  100.005680
# 8        host_acceptance_rate                      price -102.882623
# 4          host_response_rate                      price -101.854423
# 1          host_response_rate  host_total_listings_count  -99.921274
# 13  host_total_listings_count         host_response_rate  100.072622
# 19               accommodates  host_total_listings_count -100.400353
# 10  host_total_listings_count               accommodates  100.012031
# 20          reviews_per_month                      price -517.300582
# 5        host_acceptance_rate  host_total_listings_count  -99.959574
# 14  host_total_listings_count       host_acceptance_rate  100.038673
# 12  host_total_listings_count                      price  -99.362836
# 11  host_total_listings_count          reviews_per_month  100.010821
# 23          reviews_per_month  host_total_listings_count  115.207046
# 6        host_acceptance_rate               accommodates  100.003257
# 18               accommodates       host_acceptance_rate  101.041818
# 17               accommodates         host_response_rate -102.507449
# 2          host_response_rate               accommodates  100.004046
# 24          reviews_per_month               accommodates -114.003236
# 15               accommodates          reviews_per_month  101.375946
#
#              b           c        R²
# 0   -99.712921   25.583998  0.402968
# 9   -99.657403   26.666408  0.402968
# 16  365.005080  -29.514949  0.087154
# 22  119.179899   58.438945  0.051588
# 7  -100.001605    0.660692  0.051588
# 21  119.401967   63.562396  0.047037
# 3  -100.001311    0.679629  0.047037
# 8    97.125583  994.199545  0.041951
# 4    98.152567  873.402538  0.020696
# 1   100.085717    3.513092  0.020446
# 13  -99.948290   72.420986  0.020446
# 19  102.345763    8.307169  0.006127
# 10 -100.008881    3.773231  0.006127
# 20  426.702881  689.075020  0.005029
# 5   100.048632    9.616106  0.005026
# 14  -99.982239   67.920364  0.005026
# 12  100.658076  577.671645  0.003351
# 11 -100.010091    0.993080  0.001734
# 23 -112.829904   13.356135  0.001734
# 6  -100.004950    3.939283  0.001121
# 18 -101.704298   71.341420  0.001121
# 17  103.021884   72.411901  0.000567
# 2  -100.002944    3.740887  0.000567
# 24  114.033714    3.792202  0.000176
# 15 -101.370171    0.982484  0.000176

# %%
# Graficar los mejores dos modelos
plt.figure(figsize=(12, 6))

# Obtener los dos mejores modelos
mejores_modelos = df_resultados.head(2)

# Usar enumerate para obtener el índice correcto para las subgráficas
for i, (index, row) in enumerate(mejores_modelos.iterrows()):
    var1 = row['Variable 1']
    var2 = row['Variable 2']
    a = row['a']
    b = row['b']
    c = row['c']

    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]
    # Use func1 instead of func_cuadratica
    yfit = func1(x, a, b, c)

    plt.subplot(1, 2, i + 1)  # Usar i en lugar de index
    plt.scatter(x, y, label='Datos reales', alpha=0.5)
    plt.plot(x, yfit, color='red', label='Ajuste cuadrático')
    plt.title(f'Ajuste para {var1} vs {var2}\nR² = {row["R²"]:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Regresión No Lineal - Función Exponencial**

# %%
# Definir la función exponencial
def func_exponencial(x, a, b, c):
    return a * np.exp(b * x) + c

# Lista para almacenar los resultados
resultados2 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros2, _ = curve_fit(func_exponencial, x, y)
    a, b, c = parametros2 # Use parametros2 instead of parametros
    yfit2 = func_exponencial(x, a, b, c)

    # Calcular el coeficiente de determinación
    R2_2 = r2_score(y, yfit2)

    # Almacenar los resultados en la lista
    resultados2.append((var1, var2, a, b, c, R2_2))

# Crear un DataFrame a partir de los resultados
df_resultados2 = pd.DataFrame(resultados2, columns=['Variable 1', 'Variable 2', 'a', 'b', 'c', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados2 = df_resultados2.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados2
# Out:
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: RuntimeWarning: overflow encountered in square
#   cost = np.sum(infodict['fvec'] ** 2)
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1048: RuntimeWarning: invalid value encountered in multiply
#   pcov = pcov * s_sq
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:1220: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: RuntimeWarning: overflow encountered in square
#   cost = np.sum(infodict['fvec'] ** 2)
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1048: RuntimeWarning: invalid value encountered in multiply
#   pcov = pcov * s_sq
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:1220: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: RuntimeWarning: overflow encountered in square
#   cost = np.sum(infodict['fvec'] ** 2)
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1048: RuntimeWarning: invalid value encountered in multiply
#   pcov = pcov * s_sq
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:1220: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: RuntimeWarning: overflow encountered in square
#   cost = np.sum(infodict['fvec'] ** 2)
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1048: RuntimeWarning: invalid value encountered in multiply
#   pcov = pcov * s_sq
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:1220: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: RuntimeWarning: overflow encountered in square
#   cost = np.sum(infodict['fvec'] ** 2)
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1048: RuntimeWarning: invalid value encountered in multiply
#   pcov = pcov * s_sq
# c:\Users\Osvaldo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:1220: RuntimeWarning: overflow encountered in square
#   numerator = xp.sum(weight * (y_true - y_pred) ** 2, axis=0)
#                    Variable 1                 Variable 2             a  \
# 16               accommodates                      price  3.075767e+02
# 22          reviews_per_month       host_acceptance_rate  2.667841e+01
# 21          reviews_per_month         host_response_rate  1.696794e+03
# 20          reviews_per_month                      price -5.794929e+01
# 19               accommodates  host_total_listings_count  1.616351e+04
# 18               accommodates       host_acceptance_rate -1.374566e-01
# 23          reviews_per_month  host_total_listings_count  9.187901e+03
# 24          reviews_per_month               accommodates  5.618142e+01
# 15               accommodates          reviews_per_month -6.793615e-05
# 17               accommodates         host_response_rate -1.058070e-04
# 8        host_acceptance_rate                      price  2.612232e-20
# 5        host_acceptance_rate  host_total_listings_count  2.612232e-20
# 9        host_acceptance_rate         host_response_rate  2.612232e-20
# 6        host_acceptance_rate               accommodates  2.612232e-20
# 7        host_acceptance_rate          reviews_per_month  2.612232e-20
# 4          host_response_rate                      price -6.280400e-15
# 1          host_response_rate  host_total_listings_count -6.280400e-15
# 0          host_response_rate       host_acceptance_rate -6.280400e-15
# 2          host_response_rate               accommodates -6.280400e-15
# 3          host_response_rate          reviews_per_month -6.280400e-15
# 14  host_total_listings_count       host_acceptance_rate -2.181674e-15
# 13  host_total_listings_count         host_response_rate -2.181674e-15
# 11  host_total_listings_count          reviews_per_month -2.181674e-15
# 10  host_total_listings_count               accommodates -2.181674e-15
# 12  host_total_listings_count                      price -2.181674e-15
#
#            b              c            R²
# 16  0.195533  -1.018674e+02  9.392101e-02
# 22  0.255069   3.351901e+01  5.343284e-02
# 21  0.006283  -1.633183e+03  4.703720e-02
# 20  0.582042   7.175170e+02  6.470446e-03
# 19  0.000120  -1.615520e+04  6.126527e-03
# 18  0.448184   7.001233e+01  2.436925e-03
# 23  0.000258  -9.174544e+03  1.733025e-03
# 24  0.000541  -5.238917e+01  1.757899e-04
# 15  0.685431   1.007603e+00  1.351937e-04
# 17  0.880149   7.440166e+01  6.808621e-06
# 8   1.000000   3.904174e+02 -1.156065e+41
# 5   1.000000  -1.036652e+02 -5.787788e+43
# 9   1.000000  -9.634568e+00 -7.654977e+43
# 6   1.000000  -9.418443e+00 -3.574916e+46
# 7   1.000000   4.563018e-01 -1.886653e+47
# 4   1.000000   1.000000e+00 -1.533518e+52
# 1   1.000000   1.000000e+00 -7.677485e+54
# 0   1.000000   1.000000e+00 -1.211568e+55
# 2   1.000000   1.000000e+00 -4.742116e+57
# 3   1.000000   1.000000e+00 -2.502639e+58
# 14  1.000000  1.175544e+140          -inf
# 13  1.000000  1.176088e+140          -inf
# 11  1.000000  1.176100e+140          -inf
# 10  1.000000  1.175800e+140          -inf
# 12  1.000000  1.175788e+140          -inf

# %% [markdown]
# **Regresión No Lineal - Función Inversa**

# %%
# Definir la función inversa
def func_inversa(x, a):
    return 1 / a * x

# Lista para almacenar los resultados
resultados3 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros3, _ = curve_fit(func_inversa, x, y)
    a = parametros3[0]
    yfit3 = func_inversa(x, a)

    # Calcular el coeficiente de determinación
    R2_3 = r2_score(y, yfit3)

    # Almacenar los resultados en la lista
    resultados3.append((var1, var2, a, R2_3))

# Crear un DataFrame a partir de los resultados
df_resultados3 = pd.DataFrame(resultados3, columns=['Variable 1', 'Variable 2', 'a', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados3 = df_resultados3.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados3
# Out:
#                    Variable 1                 Variable 2           a        R²
# 9        host_acceptance_rate         host_response_rate    1.005464  0.305148
# 0          host_response_rate       host_acceptance_rate    1.180362  0.293778
# 16               accommodates                      price    0.006332  0.086998
# 1          host_response_rate  host_total_listings_count    4.975718  0.019141
# 19               accommodates  host_total_listings_count    0.270158 -0.000051
# 5        host_acceptance_rate  host_total_listings_count    5.059164 -0.004592
# 23          reviews_per_month  host_total_listings_count    0.095896 -0.031104
# 7        host_acceptance_rate          reviews_per_month   80.261990 -0.096406
# 3          host_response_rate          reviews_per_month   87.441959 -0.112125
# 4          host_response_rate                      price    0.185848 -0.140375
# 8        host_acceptance_rate                      price    0.182773 -0.163395
# 20          reviews_per_month                      price    0.003079 -0.169555
# 12  host_total_listings_count                      price    0.196104 -0.275443
# 15               accommodates          reviews_per_month    4.684458 -0.281531
# 17               accommodates         host_response_rate    0.063202 -0.620329
# 18               accommodates       host_acceptance_rate    0.069353 -0.717962
# 2          host_response_rate               accommodates   24.997895 -0.913165
# 21          reviews_per_month         host_response_rate    0.020374 -0.936599
# 22          reviews_per_month       host_acceptance_rate    0.021955 -0.940468
# 6        host_acceptance_rate               accommodates   23.366124 -0.995788
# 11  host_total_listings_count          reviews_per_month  137.572456 -1.342887
# 24          reviews_per_month               accommodates    0.431716 -1.634903
# 13  host_total_listings_count         host_response_rate    1.663228 -2.880983
# 14  host_total_listings_count       host_acceptance_rate    1.985289 -3.039926
# 10  host_total_listings_count               accommodates   35.717884 -3.672042

# %%
# Graficar los mejores dos modelos
plt.figure(figsize=(12, 6))

# Obtener los dos mejores modelos
mejores_modelos3 = df_resultados3.head(2)

# Usar enumerate para obtener el índice correcto para las subgráficas
for i, (index, row) in enumerate(mejores_modelos3.iterrows()):
    var1 = row['Variable 1']
    var2 = row['Variable 2']
    a = row['a']

    x = Rio_de_janeiro_outliers[var1].values
    y = Rio_de_janeiro_outliers[var2].values
    yfit3 = func_inversa(x, a)

    plt.subplot(1, 2, i + 1)  # Usar i para la subgráfica
    plt.scatter(x, y, label='Datos reales', alpha=0.5)
    plt.plot(x, yfit3, color='red', label='Ajuste inverso')
    plt.title(f'Ajuste para {var1} vs {var2}\nR² = {row["R²"]:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Regresión No Lineal - Función Senoidal**

# %%
# Definir la función senoidal
def func_senoidal(x, a, b):
    return a * np.sin(x) + b

# Lista para almacenar los resultados
resultados4 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros4, _ = curve_fit(func_senoidal, x, y)
    a, b = parametros4
    yfit4 = func_senoidal(x, a, b)

    # Calcular el coeficiente de determinación
    R2_4 = r2_score(y, yfit4)

    # Almacenar los resultados en la lista
    resultados4.append((var1, var2, a, b, R2_4))

# Crear un DataFrame a partir de los resultados
df_resultados4 = pd.DataFrame(resultados4, columns=['Variable 1', 'Variable 2', 'a', 'b', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados4 = df_resultados4.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados4
# Out:
#                    Variable 1                 Variable 2           a  \
# 0          host_response_rate       host_acceptance_rate  -27.868646
# 13  host_total_listings_count         host_response_rate   -9.564559
# 3          host_response_rate          reviews_per_month   -0.245145
# 16               accommodates                      price -150.626276
# 9        host_acceptance_rate         host_response_rate   -7.234740
# 14  host_total_listings_count       host_acceptance_rate   -5.712337
# 4          host_response_rate                      price  204.059319
# 7        host_acceptance_rate          reviews_per_month   -0.096517
# 19               accommodates  host_total_listings_count   -3.828537
# 5        host_acceptance_rate  host_total_listings_count   -3.761294
# 20          reviews_per_month                      price  132.350144
# 23          reviews_per_month  host_total_listings_count    5.788791
# 15               accommodates          reviews_per_month   -0.046951
# 8        host_acceptance_rate                      price   64.379966
# 1          host_response_rate  host_total_listings_count   -3.854986
# 22          reviews_per_month       host_acceptance_rate   -3.375735
# 17               accommodates         host_response_rate   -1.747283
# 24          reviews_per_month               accommodates    0.146427
# 12  host_total_listings_count                      price  -35.198764
# 10  host_total_listings_count               accommodates   -0.059047
# 21          reviews_per_month         host_response_rate    1.917727
# 2          host_response_rate               accommodates    0.059196
# 11  host_total_listings_count          reviews_per_month   -0.012146
# 6        host_acceptance_rate               accommodates   -0.011295
# 18               accommodates       host_acceptance_rate   -0.062472
#
#              b        R²
# 0    60.803295  0.109306
# 13   77.656241  0.025750
# 3     0.934141  0.017471
# 16  597.121392  0.011730
# 9    73.152455  0.011187
# 14   70.766484  0.010959
# 4   656.682394  0.007418
# 7     0.988205  0.004907
# 19   15.720160  0.003794
# 5    15.106713  0.002286
# 20  520.728856  0.002226
# 23   12.361599  0.002132
# 15    1.004268  0.001860
# 8   608.974215  0.001338
# 1    14.636733  0.001325
# 22   70.781398  0.001144
# 17   74.367555  0.001045
# 24    3.737259  0.000843
# 12  610.126602  0.000527
# 10    3.843054  0.000458
# 21   73.257919  0.000309
# 2     3.839824  0.000193
# 11    1.008724  0.000102
# 6     3.820905  0.000013
# 18   68.808488  0.000002

# %%
# Graficar los mejores dos modelos
plt.figure(figsize=(12, 6))

# Obtener los dos mejores modelos
mejores_modelos4 = df_resultados4.head(2)

# Usar enumerate para obtener el índice correcto para las subgráficas
for i, (index, row) in enumerate(mejores_modelos4.iterrows()):
    var1 = row['Variable 1']
    var2 = row['Variable 2']
    a = row['a']
    b = row['b']

    x = Rio_de_janeiro_outliers[var1].values
    y = Rio_de_janeiro_outliers[var2].values
    yfit4 = func_senoidal(x, a, b)

    plt.subplot(1, 2, i + 1)  # Usar i para la subgráfica
    plt.scatter(x, y, label='Datos reales', alpha=0.5)
    plt.plot(x, yfit4, color='red', label='Ajuste senoidal')
    plt.title(f'Ajuste para {var1} vs {var2}\nR² = {row["R²"]:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Regresión No Lineal - Función Tangencial**

# %%
# Definir la función tangencial
def func_tangencial(x, a, b):
    return a * np.tan(x) + b

# Lista para almacenar los resultados
resultados5 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros5, _ = curve_fit(func_tangencial, x, y)
    a, b = parametros5
    yfit5 = func_tangencial(x, a, b)

    # Calcular el coeficiente de determinación
    R2_5 = r2_score(y, yfit5)

    # Almacenar los resultados en la lista
    resultados5.append((var1, var2, a, b, R2_5))


# Crear un DataFrame a partir de los resultados
df_resultados5 = pd.DataFrame(resultados5, columns=['Variable 1', 'Variable 2', 'a', 'b', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados5 = df_resultados5.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados5
# Out:
#                    Variable 1                 Variable 2         a  \
# 5        host_acceptance_rate  host_total_listings_count -0.251185
# 13  host_total_listings_count         host_response_rate -0.070576
# 14  host_total_listings_count       host_acceptance_rate -0.057629
# 16               accommodates                      price -4.968627
# 1          host_response_rate  host_total_listings_count -0.234463
# 7        host_acceptance_rate          reviews_per_month -0.002113
# 9        host_acceptance_rate         host_response_rate -0.084138
# 8        host_acceptance_rate                      price  2.120108
# 4          host_response_rate                      price  2.752663
# 19               accommodates  host_total_listings_count -0.091772
# 22          reviews_per_month       host_acceptance_rate  0.010449
# 17               accommodates         host_response_rate -0.061532
# 21          reviews_per_month         host_response_rate  0.009800
# 23          reviews_per_month  host_total_listings_count -0.008654
# 24          reviews_per_month               accommodates -0.000345
# 6        host_acceptance_rate               accommodates  0.001202
# 20          reviews_per_month                      price -0.145660
# 10  host_total_listings_count               accommodates -0.000375
# 11  host_total_listings_count          reviews_per_month -0.000158
# 2          host_response_rate               accommodates -0.001265
# 0          host_response_rate       host_acceptance_rate -0.024509
# 3          host_response_rate          reviews_per_month -0.000202
# 12  host_total_listings_count                      price -0.023140
# 15               accommodates          reviews_per_month  0.000023
# 18               accommodates       host_acceptance_rate -0.000268
#
#              b            R²
# 5    15.052464  4.654730e-03
# 13   74.121412  2.178584e-03
# 14   68.598961  1.733166e-03
# 16  593.548214  1.331546e-03
# 1    15.515429  1.317556e-03
# 7     0.998744  1.073580e-03
# 9    74.146809  6.907608e-04
# 8   603.901937  6.623598e-04
# 4   600.748968  3.627430e-04
# 19   15.660712  2.274204e-04
# 22   68.785518  1.570961e-04
# 17   74.322566  1.352233e-04
# 21   74.356580  1.158193e-04
# 23   15.763469  6.828434e-05
# 24    3.823590  6.703929e-05
# 6     3.826128  6.580899e-05
# 20  598.389723  3.863988e-05
# 10    3.821454  2.869378e-05
# 11    1.003986  2.686542e-05
# 2     3.821585  2.369412e-05
# 0    68.784974  2.272284e-05
# 3     1.004364  3.202701e-06
# 12  597.979773  3.536688e-07
# 15    1.004583  4.813409e-08
# 18   68.808636  3.072599e-09

# %% [markdown]
# **Regresión No Lineal - Valor absoluto**

# %%
# Definir la función valor absoluto
def func_valor_absoluto(x, a, b, c):
    return a * np.abs(x) + b * x + c

# Lista para almacenar los resultados
resultados6 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros6, _ = curve_fit(func_valor_absoluto, x, y)
    a, b, c = parametros6
    yfit6 = func_valor_absoluto(x, a, b, c)

    # Calcular el coeficiente de determinación
    R2_6 = r2_score(y, yfit6)

    # Almacenar los resultados en la lista
    resultados6.append((var1, var2, a, b, c, R2_6))

# Crear un DataFrame a partir de los resultados
df_resultados6 = pd.DataFrame(resultados6, columns=['Variable 1', 'Variable 2', 'a', 'b', 'c', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados6 = df_resultados6.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados6
# Out:
#                    Variable 1                 Variable 2           a  \
# 0          host_response_rate       host_acceptance_rate  100.294069
# 9        host_acceptance_rate         host_response_rate  100.350803
# 16               accommodates                      price -200.838547
# 22          reviews_per_month       host_acceptance_rate -108.857052
# 7        host_acceptance_rate          reviews_per_month  100.006602
# 21          reviews_per_month         host_response_rate -108.634985
# 3          host_response_rate          reviews_per_month  100.005680
# 8        host_acceptance_rate                      price -102.882623
# 4          host_response_rate                      price -101.854423
# 1          host_response_rate  host_total_listings_count  -99.921274
# 13  host_total_listings_count         host_response_rate  100.072622
# 19               accommodates  host_total_listings_count -100.400353
# 10  host_total_listings_count               accommodates  100.012031
# 20          reviews_per_month                      price -517.300582
# 5        host_acceptance_rate  host_total_listings_count  -99.959574
# 14  host_total_listings_count       host_acceptance_rate  100.038673
# 12  host_total_listings_count                      price  -99.362836
# 11  host_total_listings_count          reviews_per_month  100.010821
# 23          reviews_per_month  host_total_listings_count  115.207046
# 6        host_acceptance_rate               accommodates  100.003257
# 18               accommodates       host_acceptance_rate  101.041818
# 17               accommodates         host_response_rate -102.507449
# 2          host_response_rate               accommodates  100.004046
# 24          reviews_per_month               accommodates -114.003236
# 15               accommodates          reviews_per_month  101.375946
#
#              b           c        R²
# 0   -99.712921   25.583998  0.402968
# 9   -99.657403   26.666408  0.402968
# 16  365.005080  -29.514949  0.087154
# 22  119.179899   58.438945  0.051588
# 7  -100.001605    0.660692  0.051588
# 21  119.401967   63.562396  0.047037
# 3  -100.001311    0.679629  0.047037
# 8    97.125583  994.199545  0.041951
# 4    98.152567  873.402538  0.020696
# 1   100.085717    3.513092  0.020446
# 13  -99.948290   72.420986  0.020446
# 19  102.345763    8.307169  0.006127
# 10 -100.008881    3.773231  0.006127
# 20  426.702881  689.075020  0.005029
# 5   100.048632    9.616106  0.005026
# 14  -99.982239   67.920364  0.005026
# 12  100.658076  577.671645  0.003351
# 11 -100.010091    0.993080  0.001734
# 23 -112.829904   13.356135  0.001734
# 6  -100.004950    3.939283  0.001121
# 18 -101.704298   71.341420  0.001121
# 17  103.021884   72.411901  0.000567
# 2  -100.002944    3.740887  0.000567
# 24  114.033714    3.792202  0.000176
# 15 -101.370171    0.982484  0.000176

# %%
# Obtener los dos mejores modelos
mejores_modelos6 = df_resultados6.head(2)

# Usar enumerate para obtener el índice correcto para las subgráficas
for i, (index, row) in enumerate(mejores_modelos6.iterrows()):
    var1 = row['Variable 1']
    var2 = row['Variable 2']
    a = row['a']
    b = row['b']
    c = row['c']

    x = Rio_de_janeiro_outliers[var1].values
    y = Rio_de_janeiro_outliers[var2].values
    yfit6 = func_valor_absoluto(x, a, b, c)

    plt.subplot(1, 2, i + 1)  # Usar i para la subgráfica
    plt.scatter(x, y, label='Datos reales', alpha=0.5)
    plt.plot(x, yfit6, color='red', label='Ajuste valor absoluto')
    plt.title(f'Ajuste para \n{var1} vs {var2}\nR² = {row["R²"]:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Regresión No Lineal - Cociente entre polinomios**

# %%
# Definir la función cociente entre polinomios
def func_cociente_polinomios(x, a, b, c):
    return (a * x**2 + b) / (c * x + 1e-7)

# Lista para almacenar los resultados
resultados7 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros7, _ = curve_fit(func_cociente_polinomios, x, y)
    a, b, c = parametros7
    yfit7 = func_cociente_polinomios(x, a, b, c)

    # Calcular el coeficiente de determinación
    R2_7 = r2_score(y, yfit7)

    # Almacenar los resultados en la lista
    resultados7.append((var1, var2, a, b, c, R2_7))

# Crear un DataFrame a partir de los resultados
df_resultados7 = pd.DataFrame(resultados7, columns=['Variable 1', 'Variable 2', 'a', 'b', 'c', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados7 = df_resultados7.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados7
# Out:
#                    Variable 1                 Variable 2             a  \
# 0          host_response_rate       host_acceptance_rate -1.165047e+03
# 9        host_acceptance_rate         host_response_rate -9.377093e+04
# 16               accommodates                      price  1.819279e+01
# 7        host_acceptance_rate          reviews_per_month -5.374818e+04
# 22          reviews_per_month       host_acceptance_rate  1.194809e-07
# 3          host_response_rate          reviews_per_month -6.027693e+03
# 21          reviews_per_month         host_response_rate -2.419852e-07
# 13  host_total_listings_count         host_response_rate -3.675754e-11
# 1          host_response_rate  host_total_listings_count -1.800085e+05
# 10  host_total_listings_count               accommodates -1.758267e-12
# 4          host_response_rate                      price -9.498680e+03
# 20          reviews_per_month                      price -3.511437e-06
# 14  host_total_listings_count       host_acceptance_rate -1.645743e-11
# 19               accommodates  host_total_listings_count  7.580654e+00
# 23          reviews_per_month  host_total_listings_count -6.826099e-08
# 11  host_total_listings_count          reviews_per_month -2.396822e-13
# 24          reviews_per_month               accommodates -4.413026e-09
# 5        host_acceptance_rate  host_total_listings_count -8.114215e+01
# 8        host_acceptance_rate                      price -8.799637e+04
# 15               accommodates          reviews_per_month  4.967007e-02
# 12  host_total_listings_count                      price  6.604205e+02
# 2          host_response_rate               accommodates -1.739557e+00
# 17               accommodates         host_response_rate  1.137970e+03
# 18               accommodates       host_acceptance_rate  1.637868e+02
# 6        host_acceptance_rate               accommodates -2.502136e+03
#
#                b             c        R²
# 0   2.776626e-06 -1.375173e+03  0.408345
# 9   1.520668e-06 -9.428130e+04  0.327817
# 16  2.990065e+00  1.162441e-01  0.087057
# 7   8.464312e-08 -4.313745e+06  0.076698
# 22  6.168748e-06 -6.793099e-09  0.053251
# 3   7.273524e-08 -5.270753e+05  0.050268
# 21  6.276618e-06 -1.909847e-08  0.047228
# 13  7.242174e-06 -2.132743e-10  0.025425
# 1   2.724918e-07 -8.956398e+05  0.019840
# 10  3.741379e-07 -1.883883e-10  0.011525
# 4   8.939879e-05 -1.765341e+03  0.009950
# 20  6.346090e-05 -4.099667e-09  0.007261
# 14  6.768174e-06 -1.269808e-10  0.005542
# 19  2.258788e+01  2.385668e+00  0.003917
# 23  1.338178e-06 -2.093876e-08  0.002251
# 11  9.889732e-08 -1.228873e-10  0.001942
# 24  3.727928e-07 -4.363848e-09  0.000815
# 5   2.863749e-07 -4.105287e+02 -0.003984
# 8   9.873867e-05 -1.608305e+04 -0.019054
# 15  4.255015e-01  3.428894e-01 -0.059392
# 12  1.019053e+05  1.378753e+02 -0.097384
# 2   3.720000e-07 -4.348503e+01 -0.108276
# 17  9.890889e+03  1.064913e+02 -0.115480
# 18  1.605873e+03  1.751797e+01 -0.131236
# 6   3.905085e-07 -5.846419e+04 -0.297620

# %%
# Graficar los mejores dos modelos
plt.figure(figsize=(12, 6))

# Obtener los dos mejores modelos
mejores_modelos7 = df_resultados7.head(2)

# Usar enumerate para obtener el índice correcto para las subgráficas
for i, (index, row) in enumerate(mejores_modelos7.iterrows()):
    var1 = row['Variable 1']
    var2 = row['Variable 2']
    a = row['a']
    b = row['b']
    c = row['c']

    x = Rio_de_janeiro_outliers[var1].values
    y = Rio_de_janeiro_outliers[var2].values
    yfit7 = func_cociente_polinomios(x, a, b, c)

    plt.subplot(1, 2, i + 1)  # Usar i para la subgráfica
    plt.scatter(x, y, label='Datos reales', alpha=0.5)
    plt.plot(x, yfit7, color='red', label='Ajuste cociente polinomios')
    plt.title(f'Ajuste para {var1} vs {var2}\nR² = {row["R²"]:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Regresión No Lineal - Logaritmica**

# %%
# Definir la función logarítmica
def func_logaritmica(x, a, b):
    return a * np.log(x + 1e-7) + b  # Evitar log(0)

# Lista para almacenar los resultados
resultados8 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros8, _ = curve_fit(func_logaritmica, x, y)
    a, b = parametros8
    yfit8 = func_logaritmica(x, a, b)

    # Calcular el coeficiente de determinación
    R2_8 = r2_score(y, yfit8)

    # Almacenar los resultados en la lista
    resultados8.append((var1, var2, a, b, R2_8))

# Crear un DataFrame a partir de los resultados
df_resultados8 = pd.DataFrame(resultados8, columns=['Variable 1', 'Variable 2', 'a', 'b', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados8 = df_resultados8.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados8
# Out:
#                    Variable 1                 Variable 2           a  \
# 9        host_acceptance_rate         host_response_rate    3.487718
# 0          host_response_rate       host_acceptance_rate    2.533549
# 13  host_total_listings_count         host_response_rate    8.189698
# 16               accommodates                      price  536.999968
# 21          reviews_per_month         host_response_rate    7.868542
# 22          reviews_per_month       host_acceptance_rate    7.029027
# 3          host_response_rate          reviews_per_month    0.017250
# 14  host_total_listings_count       host_acceptance_rate    4.621537
# 8        host_acceptance_rate                      price  -23.627824
# 4          host_response_rate                      price  -18.037296
# 1          host_response_rate  host_total_listings_count    0.796738
# 5        host_acceptance_rate  host_total_listings_count    0.723169
# 7        host_acceptance_rate          reviews_per_month    0.010547
# 10  host_total_listings_count               accommodates    0.114167
# 19               accommodates  host_total_listings_count    7.698157
# 12  host_total_listings_count                      price   57.087319
# 20          reviews_per_month                      price  -48.271117
# 23          reviews_per_month  host_total_listings_count    1.973847
# 11  host_total_listings_count          reviews_per_month    0.023832
# 17               accommodates         host_response_rate    3.260912
# 15               accommodates          reviews_per_month    0.051310
# 2          host_response_rate               accommodates    0.006197
# 6        host_acceptance_rate               accommodates   -0.005324
# 24          reviews_per_month               accommodates    0.028966
# 18               accommodates       host_acceptance_rate   -0.942477
#
#              b        R²
# 9    70.598746  0.420777
# 0    67.944408  0.324104
# 13   62.950321  0.080249
# 16  -57.388620  0.068400
# 21   77.845190  0.049059
# 22   71.905708  0.046711
# 3     0.998676  0.031036
# 14   62.359838  0.030491
# 8   623.670245  0.029165
# 4   604.218567  0.020793
# 1    15.472266  0.020311
# 5    14.960400  0.013678
# 7     0.993131  0.009484
# 10    3.663507  0.007283
# 19    6.347885  0.007037
# 12  518.402577  0.005889
# 20  576.796914  0.002788
# 23   16.613753  0.002334
# 11    0.971306  0.001675
# 17   70.398279  0.001670
# 15    0.941934  0.001019
# 2     3.820705  0.000759
# 6     3.828589  0.000458
# 24    3.835581  0.000310
# 18   69.959251  0.000166

# %%
# Graficar los dos mejores modelos logarítmicos
plt.figure(figsize=(12, 6))

# Obtener los dos mejores modelos
mejores_modelos8 = df_resultados8.head(2)

# Usar enumerate para obtener el índice correcto para las subgráficas
for i, (index, row) in enumerate(mejores_modelos8.iterrows()):
    var1 = row['Variable 1']
    var2 = row['Variable 2']
    a = row['a']
    b = row['b']

    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]
    yfit8 = func_logaritmica(x, a, b)

    plt.subplot(1, 2, i + 1)  # Usar i para la subgráfica
    plt.scatter(x, y, label='Datos reales', alpha=0.5)
    plt.plot(x, yfit8, color='red', label='Ajuste logarítmico')
    plt.title(f'Ajuste para {var1} vs {var2}\nR² = {row["R²"]:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Regresión No Lineal - Con producto de coeficientes**

# %%
# Definir la función lineal con producto de coeficientes
def func_lineal_producto(x, a, b, c):
    return a * x + b * x + c * x

# Lista para almacenar los resultados
resultados9 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros9, _ = curve_fit(func_lineal_producto, x, y)
    a, b, c = parametros9
    yfit9 = func_lineal_producto(x, a, b, c)

    # Calcular el coeficiente de determinación
    R2_9 = r2_score(y, yfit9)

    # Almacenar los resultados en la lista
    resultados9.append((var1, var2, a, b, c, R2_9))

# Crear un DataFrame a partir de los resultados
df_resultados9 = pd.DataFrame(resultados9, columns=['Variable 1', 'Variable 2', 'a', 'b', 'c', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados9 = df_resultados9.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados9
# Out:
#                    Variable 1                 Variable 2           a  \
# 9        host_acceptance_rate         host_response_rate  141.754055
# 0          host_response_rate       host_acceptance_rate  141.703756
# 16               accommodates                      price  174.669048
# 1          host_response_rate  host_total_listings_count -141.354364
# 19               accommodates  host_total_listings_count -140.187509
# 5        host_acceptance_rate  host_total_listings_count -141.355471
# 23          reviews_per_month  host_total_listings_count   74.187032
# 7        host_acceptance_rate          reviews_per_month  141.439030
# 3          host_response_rate          reviews_per_month  141.426770
# 4          host_response_rate                      price -139.627778
# 8        host_acceptance_rate                      price -139.597598
# 20          reviews_per_month                      price -200.712952
# 12  host_total_listings_count                      price  143.121134
# 15               accommodates          reviews_per_month  141.492514
# 17               accommodates         host_response_rate  146.695449
# 18               accommodates       host_acceptance_rate -136.615001
# 2          host_response_rate               accommodates  141.435164
# 21          reviews_per_month         host_response_rate   88.066393
# 22          reviews_per_month       host_acceptance_rate   86.761270
# 6        host_acceptance_rate               accommodates  141.449441
# 11  host_total_listings_count          reviews_per_month  141.423810
# 24          reviews_per_month               accommodates  -69.938415
# 13  host_total_listings_count         host_response_rate  141.621770
# 14  host_total_listings_count       host_acceptance_rate  141.589258
# 10  host_total_listings_count               accommodates  141.430689
#
#              b           c        R²
# 9   -70.379745  -70.379745  0.305148
# 0   -70.428279  -70.428279  0.293778
# 16   -8.370946   -8.370946  0.086998
# 1    70.777670   70.777670  0.019141
# 19   71.944526   71.944526 -0.000051
# 5    70.776566   70.776566 -0.004592
# 23   74.186288 -137.945374 -0.031104
# 7   -70.713286  -70.713286 -0.096406
# 3   -70.707667  -70.707667 -0.112125
# 4    72.504256   72.504256 -0.140375
# 8    72.534437   72.534437 -0.163395
# 20  276.107058  249.368606 -0.169555
# 12  -69.010900  -69.010900 -0.275443
# 15  -70.639521  -70.639521 -0.281531
# 17  -65.436585  -65.436585 -0.620329
# 18   75.517033   75.517033 -0.717962
# 2   -70.697581  -70.697581 -0.913165
# 21   88.066393 -127.051687 -0.936599
# 22   86.761270 -127.973887 -0.940468
# 6   -70.703322  -70.703322 -0.995788
# 11  -70.708271  -70.708271 -1.342887
# 24  -69.938415  142.193171 -1.634903
# 13  -70.510265  -70.510265 -2.880983
# 14  -70.542776  -70.542776 -3.039926
# 10  -70.701346  -70.701346 -3.672042

# %%
# Graficar los dos mejores modelos lineales con producto de coeficientes
plt.figure(figsize=(12, 6))

# Obtener los dos mejores modelos
mejores_modelos9 = df_resultados9.head(2)

# Usar enumerate para obtener el índice correcto para las subgráficas
for i, (index, row) in enumerate(mejores_modelos9.iterrows()):
    var1 = row['Variable 1']
    var2 = row['Variable 2']
    a = row['a']
    b = row['b']
    c = row['c']

    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]
    yfit9 = func_lineal_producto(x, a, b, c)

    plt.subplot(1, 2, i + 1)  # Usar i para la subgráfica
    plt.scatter(x, y, label='Datos reales', alpha=0.5)
    plt.plot(x, yfit9, color='red', label='Ajuste lineal con producto')
    plt.title(f'Ajuste para {var1} vs {var2}\nR² = {row["R²"]:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Regresión No Lineal - Cuadrática inversa**

# %%
# Definir la función cuadrática inversa
def func_cuadratica_inversa(x, a):
    return 1 / (a * x**2 + 1e-7)  # Evitar división por cero

# Lista para almacenar los resultados
resultados10 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros10, _ = curve_fit(func_cuadratica_inversa, x, y)
    a = parametros10[0]
    yfit10 = func_cuadratica_inversa(x, a)

    # Calcular el coeficiente de determinación
    R2_10 = r2_score(y, yfit)

    # Almacenar los resultados en la lista
    resultados10.append((var1, var2, a, R2_10))

# Crear un DataFrame a partir de los resultados
df_resultados10 = pd.DataFrame(resultados10, columns=['Variable 1', 'Variable 2', 'a', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados10 = df_resultados10.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados10
# Out:
#                    Variable 1                 Variable 2            a  \
# 0          host_response_rate       host_acceptance_rate     1.000000
# 22          reviews_per_month       host_acceptance_rate   181.340844
# 18               accommodates       host_acceptance_rate     0.006242
# 14  host_total_listings_count       host_acceptance_rate     0.014228
# 13  host_total_listings_count         host_response_rate     0.013846
# 21          reviews_per_month         host_response_rate   134.558878
# 17               accommodates         host_response_rate     0.005934
# 9        host_acceptance_rate         host_response_rate     1.000000
# 20          reviews_per_month                      price     6.123271
# 16               accommodates                      price     0.001086
# 12  host_total_listings_count                      price     0.001447
# 8        host_acceptance_rate                      price     1.000000
# 4          host_response_rate                      price     1.000000
# 1          host_response_rate  host_total_listings_count     1.000000
# 5        host_acceptance_rate  host_total_listings_count     1.000000
# 19               accommodates  host_total_listings_count     0.036619
# 23          reviews_per_month  host_total_listings_count   512.226402
# 10  host_total_listings_count               accommodates     0.224534
# 6        host_acceptance_rate               accommodates     1.000000
# 2          host_response_rate               accommodates     1.000000
# 24          reviews_per_month               accommodates  1465.878889
# 11  host_total_listings_count          reviews_per_month     0.857960
# 15               accommodates          reviews_per_month     0.444885
# 7        host_acceptance_rate          reviews_per_month     1.000000
# 3          host_response_rate          reviews_per_month     1.000000
#
#              R²
# 0      0.883153
# 22     0.883153
# 18     0.883153
# 14     0.883153
# 13     0.402968
# 21     0.402968
# 17     0.402968
# 9      0.402968
# 20    -0.266336
# 16    -0.266336
# 12    -0.266336
# 8     -0.266336
# 4     -0.266336
# 1     -1.830738
# 5     -1.830738
# 19    -1.830738
# 23    -1.830738
# 10 -1623.951587
# 6  -1623.951587
# 2  -1623.951587
# 24 -1623.951587
# 11 -9168.216757
# 15 -9168.216757
# 7  -9168.216757
# 3  -9168.216757

# %%
# Graficar los dos mejores modelos de la función cuadrática inversa
plt.figure(figsize=(12, 6))

# Obtener los dos mejores modelos
mejores_modelos10 = df_resultados10.head(2)

# Usar enumerate para obtener el índice correcto para las subgráficas
for i, (index, row) in enumerate(mejores_modelos10.iterrows()):
    var1 = row['Variable 1']
    var2 = row['Variable 2']
    a = row['a']

    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]
    yfit10 = func_cuadratica_inversa(x, a)

    plt.subplot(1, 2, i + 1)  # Usar i para la subgráfica
    plt.scatter(x, y, label='Datos reales', alpha=0.5)
    plt.plot(x, yfit10, color='red', label='Ajuste cuadrático inverso')
    plt.title(f'Ajuste para {var1} vs {var2}\nR² = {row["R²"]:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Regresión No Lineal - Polinomial inversa**

# %%
# Definir la función polinomial inversa
def func_polinomial_inversa(x, a, b, c):
    return a / (x**2 + b * x + 1e-7) + c  # Evitar división por cero

# Lista para almacenar los resultados
resultados11 = []

# Calcular y mostrar la regresión no lineal para cada par de variables
for var1, var2 in variables:
    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]

    # Ajustar el modelo no lineal
    parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
    a, b, c = parametros11
    yfit11 = func_polinomial_inversa(x, a, b, c)

    # Calcular el coeficiente de determinación
    R2_11 = r2_score(y, yfit11)

    # Almacenar los resultados en la lista
    resultados11.append((var1, var2, a, b, c, R2_11))

# Crear un DataFrame a partir de los resultados
df_resultados11 = pd.DataFrame(resultados11, columns=['Variable 1', 'Variable 2', 'a', 'b', 'c', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados11 = df_resultados11.sort_values(by='R²', ascending=False)

# Mostrar la tabla
df_resultados11
# Out:
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
# C:\Users\Osvaldo\AppData\Local\Temp\ipykernel_35408\2548997357.py:14: OptimizeWarning: Covariance of the parameters could not be estimated
#   parametros11, _ = curve_fit(func_polinomial_inversa, x, y)
#                    Variable 1                 Variable 2             a  \
# 9        host_acceptance_rate         host_response_rate -7.034541e-06
# 0          host_response_rate       host_acceptance_rate -5.141860e-06
# 13  host_total_listings_count         host_response_rate  4.251338e+03
# 16               accommodates                      price -6.144806e+06
# 14  host_total_listings_count       host_acceptance_rate  1.901486e+03
# 22          reviews_per_month       host_acceptance_rate  2.391631e+03
# 21          reviews_per_month         host_response_rate  2.807288e+03
# 3          host_response_rate          reviews_per_month -3.472903e-08
# 8        host_acceptance_rate                      price  4.628397e-05
# 4          host_response_rate                      price  3.707364e-05
# 1          host_response_rate  host_total_listings_count -1.631059e-06
# 5        host_acceptance_rate  host_total_listings_count -1.531262e-06
# 7        host_acceptance_rate          reviews_per_month -1.879906e-08
# 19               accommodates  host_total_listings_count  2.295184e+04
# 17               accommodates         host_response_rate -5.685221e+00
# 15               accommodates          reviews_per_month -1.525803e-01
# 20          reviews_per_month                      price  5.419529e+03
# 10  host_total_listings_count               accommodates  2.571557e+00
# 18               accommodates       host_acceptance_rate  2.221301e+00
# 2          host_response_rate               accommodates -1.288127e-08
# 23          reviews_per_month  host_total_listings_count  2.438822e+01
# 12  host_total_listings_count                      price -3.050869e+05
# 6        host_acceptance_rate               accommodates  9.780068e-09
# 11  host_total_listings_count          reviews_per_month -1.231246e+02
# 24          reviews_per_month               accommodates -6.437576e-01
#
#                b           c        R²
# 9   3.239482e+03   85.552095  0.408063
# 0   2.272746e+04   79.184864  0.313604
# 13 -1.395391e+02   88.516300  0.081741
# 16  5.453050e+03  977.633855  0.043252
# 14 -9.458121e+01   78.211047  0.042961
# 22 -3.135225e+03   71.773363  0.040136
# 21 -3.802710e+03   77.246942  0.031495
# 3   1.634313e+02    1.074643  0.029551
# 8  -6.645451e+04  524.547006  0.026678
# 4   3.344288e+04  523.251547  0.020635
# 1   4.095596e+03   19.035505  0.019996
# 5  -1.328662e+03   18.176364  0.014619
# 7   4.734619e+01    1.034422  0.007183
# 19 -1.187247e+03   22.274548  0.006373
# 17 -5.765805e-01   75.763720  0.004402
# 15 -3.145780e-01    1.032969  0.003011
# 20  9.293834e+02  575.419184  0.002966
# 10 -1.355400e+01    3.922793  0.002386
# 18 -1.292542e+00   68.585079  0.002324
# 2   3.637939e+01    3.848813  0.000770
# 23 -1.954943e+02   16.229512  0.000680
# 12  4.586237e+03  628.415968  0.000585
# 6  -1.110364e+08    3.807284  0.000368
# 11  3.247846e+03    1.021855  0.000310
# 24  1.229462e+03    3.824885  0.000008

# %%
# Graficar los dos mejores modelos de la función polinomial inversa
plt.figure(figsize=(12, 6))

# Obtener los dos mejores modelos
mejores_modelos11 = df_resultados11.head(2)

# Usar enumerate para obtener el índice correcto para las subgráficas
for i, (index, row) in enumerate(mejores_modelos11.iterrows()):
    var1 = row['Variable 1']
    var2 = row['Variable 2']
    a, b, c = row['a'], row['b'], row['c']

    x = Rio_de_janeiro_outliers[var1]
    y = Rio_de_janeiro_outliers[var2]
    yfit11 = func_polinomial_inversa(x, a, b, c)

    plt.subplot(1, 2, i + 1)  # Usar i para la subgráfica
    plt.scatter(x, y, label='Datos reales', alpha=0.5)
    plt.plot(x, yfit11, color='red', label='Ajuste polinómico inverso')
    plt.title(f'Ajuste para {var1} vs {var2}\nR² = {row["R²"]:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Crear listas para almacenar resultados de cada modelo
resultados_totales = []

# Agregar resultados de cada modelo
for resultados, nombre_modelo in zip(
    [resultados,resultados2,resultados3,resultados4,resultados5, resultados6, resultados7, resultados8, resultados9, resultados10, resultados11],
    ['Cuadratica','Exponencial','Inversa','Senoidal', 'Tangencial', 'Valor Absoluto', 'Cociente Polinómico', 'Logarítmica', 'Lineal Producto', 'Cuadrática Inversa', 'Polinomial Inversa']
):
    for res in resultados:
        # Agregar tipo de función y variables a la lista
        # res[-1] contiene R², y res[0], res[1] contienen las variables
        resultados_totales.append((nombre_modelo, res[0], res[1], res[-1]))  # modelo, variable1, variable2, R²

# Crear un DataFrame a partir de todos los resultados
df_resultados_totales = pd.DataFrame(resultados_totales, columns=['Tipo de Función', 'Variable 1', 'Variable 2', 'R²'])

# Ordenar el DataFrame por R² de mayor a menor
df_resultados_totales = df_resultados_totales.sort_values(by='R²', ascending=False)

# Reiniciar el índice para que comience en 1
df_resultados_totales.reset_index(drop=True, inplace=True)
df_resultados_totales.index += 1  # Iniciar la numeración desde 1

# Mostrar la tabla
df_resultados_totales
# Out:
#          Tipo de Función                 Variable 1  \
# 1     Cuadrática Inversa         host_response_rate
# 2     Cuadrática Inversa  host_total_listings_count
# 3     Cuadrática Inversa               accommodates
# 4     Cuadrática Inversa          reviews_per_month
# 5            Logarítmica       host_acceptance_rate
# 6    Cociente Polinómico         host_response_rate
# 7     Polinomial Inversa       host_acceptance_rate
# 8             Cuadratica         host_response_rate
# 9         Valor Absoluto         host_response_rate
# 10            Cuadratica       host_acceptance_rate
# 11    Cuadrática Inversa               accommodates
# 12    Cuadrática Inversa       host_acceptance_rate
# 13    Cuadrática Inversa  host_total_listings_count
# 14    Cuadrática Inversa          reviews_per_month
# 15        Valor Absoluto       host_acceptance_rate
# 16   Cociente Polinómico       host_acceptance_rate
# 17           Logarítmica         host_response_rate
# 18    Polinomial Inversa         host_response_rate
# 19       Lineal Producto       host_acceptance_rate
# 20               Inversa       host_acceptance_rate
# 21               Inversa         host_response_rate
# 22       Lineal Producto         host_response_rate
# 23              Senoidal         host_response_rate
# 24           Exponencial               accommodates
# 25            Cuadratica               accommodates
# 26        Valor Absoluto               accommodates
# 27   Cociente Polinómico               accommodates
# 28               Inversa               accommodates
# 29       Lineal Producto               accommodates
# 30    Polinomial Inversa  host_total_listings_count
# 31           Logarítmica  host_total_listings_count
# 32   Cociente Polinómico       host_acceptance_rate
# 33           Logarítmica               accommodates
# 34           Exponencial          reviews_per_month
# 35   Cociente Polinómico          reviews_per_month
# 36        Valor Absoluto          reviews_per_month
# 37            Cuadratica          reviews_per_month
# 38        Valor Absoluto       host_acceptance_rate
# 39            Cuadratica       host_acceptance_rate
# 40   Cociente Polinómico         host_response_rate
# 41           Logarítmica          reviews_per_month
# 42   Cociente Polinómico          reviews_per_month
# 43           Exponencial          reviews_per_month
# 44        Valor Absoluto          reviews_per_month
# 45            Cuadratica          reviews_per_month
# 46        Valor Absoluto         host_response_rate
# 47            Cuadratica         host_response_rate
# 48           Logarítmica          reviews_per_month
# 49    Polinomial Inversa               accommodates
# 50    Polinomial Inversa  host_total_listings_count
# 51        Valor Absoluto       host_acceptance_rate
# 52            Cuadratica       host_acceptance_rate
# 53    Polinomial Inversa          reviews_per_month
# 54    Polinomial Inversa          reviews_per_month
# 55           Logarítmica         host_response_rate
# 56           Logarítmica  host_total_listings_count
# 57    Polinomial Inversa         host_response_rate
# 58           Logarítmica       host_acceptance_rate
# 59    Polinomial Inversa       host_acceptance_rate
# 60              Senoidal  host_total_listings_count
# 61   Cociente Polinómico  host_total_listings_count
# 62           Logarítmica         host_response_rate
# 63        Valor Absoluto         host_response_rate
# 64            Cuadratica         host_response_rate
# 65    Polinomial Inversa         host_response_rate
# 66        Valor Absoluto         host_response_rate
# 67            Cuadratica         host_response_rate
# 68        Valor Absoluto  host_total_listings_count
# 69            Cuadratica  host_total_listings_count
# 70           Logarítmica         host_response_rate
# 71    Polinomial Inversa         host_response_rate
# 72   Cociente Polinómico         host_response_rate
# 73       Lineal Producto         host_response_rate
# 74               Inversa         host_response_rate
# 75              Senoidal         host_response_rate
# 76    Polinomial Inversa       host_acceptance_rate
# 77           Logarítmica       host_acceptance_rate
# 78              Senoidal               accommodates
# 79   Cociente Polinómico  host_total_listings_count
# 80              Senoidal       host_acceptance_rate
# 81              Senoidal  host_total_listings_count
# 82   Cociente Polinómico         host_response_rate
# 83           Logarítmica       host_acceptance_rate
# 84              Senoidal         host_response_rate
# 85           Logarítmica  host_total_listings_count
# 86   Cociente Polinómico          reviews_per_month
# 87    Polinomial Inversa       host_acceptance_rate
# 88           Logarítmica               accommodates
# 89           Exponencial          reviews_per_month
# 90    Polinomial Inversa               accommodates
# 91            Cuadratica               accommodates
# 92        Valor Absoluto               accommodates
# 93            Cuadratica  host_total_listings_count
# 94        Valor Absoluto  host_total_listings_count
# 95           Exponencial               accommodates
# 96           Logarítmica  host_total_listings_count
# 97   Cociente Polinómico  host_total_listings_count
# 98        Valor Absoluto          reviews_per_month
# 99            Cuadratica          reviews_per_month
# 100           Cuadratica       host_acceptance_rate
# 101       Valor Absoluto       host_acceptance_rate
# 102       Valor Absoluto  host_total_listings_count
# 103           Cuadratica  host_total_listings_count
# 104             Senoidal       host_acceptance_rate
# 105           Tangencial       host_acceptance_rate
# 106   Polinomial Inversa               accommodates
# 107  Cociente Polinómico               accommodates
# 108             Senoidal               accommodates
# 109       Valor Absoluto  host_total_listings_count
# 110           Cuadratica  host_total_listings_count
# 111   Polinomial Inversa               accommodates
# 112   Polinomial Inversa          reviews_per_month
# 113          Logarítmica          reviews_per_month
# 114          Exponencial               accommodates
# 115   Polinomial Inversa  host_total_listings_count
# 116          Logarítmica          reviews_per_month
# 117   Polinomial Inversa               accommodates
# 118             Senoidal       host_acceptance_rate
# 119  Cociente Polinómico          reviews_per_month
# 120             Senoidal          reviews_per_month
# 121           Tangencial  host_total_listings_count
# 122             Senoidal          reviews_per_month
# 123  Cociente Polinómico  host_total_listings_count
# 124             Senoidal               accommodates
# 125       Valor Absoluto  host_total_listings_count
# 126           Cuadratica  host_total_listings_count
# 127           Cuadratica          reviews_per_month
# 128       Valor Absoluto          reviews_per_month
# 129           Tangencial  host_total_listings_count
# 130          Exponencial          reviews_per_month
# 131          Logarítmica  host_total_listings_count
# 132          Logarítmica               accommodates
# 133             Senoidal       host_acceptance_rate
# 134           Tangencial               accommodates
# 135             Senoidal         host_response_rate
# 136           Tangencial         host_response_rate
# 137             Senoidal          reviews_per_month
# 138       Valor Absoluto       host_acceptance_rate
# 139           Cuadratica       host_acceptance_rate
# 140           Cuadratica               accommodates
# 141       Valor Absoluto               accommodates
# 142           Tangencial       host_acceptance_rate
# 143             Senoidal               accommodates
# 144          Logarítmica               accommodates
# 145             Senoidal          reviews_per_month
# 146  Cociente Polinómico          reviews_per_month
# 147   Polinomial Inversa         host_response_rate
# 148          Logarítmica         host_response_rate
# 149           Tangencial       host_acceptance_rate
# 150   Polinomial Inversa          reviews_per_month
# 151           Tangencial       host_acceptance_rate
# 152   Polinomial Inversa  host_total_listings_count
# 153       Valor Absoluto               accommodates
# 154           Cuadratica               accommodates
# 155           Cuadratica         host_response_rate
# 156       Valor Absoluto         host_response_rate
# 157             Senoidal  host_total_listings_count
# 158             Senoidal  host_total_listings_count
# 159          Logarítmica       host_acceptance_rate
# 160   Polinomial Inversa       host_acceptance_rate
# 161           Tangencial         host_response_rate
# 162          Logarítmica          reviews_per_month
# 163   Polinomial Inversa  host_total_listings_count
# 164             Senoidal          reviews_per_month
# 165           Tangencial               accommodates
# 166             Senoidal         host_response_rate
# 167           Cuadratica          reviews_per_month
# 168       Valor Absoluto          reviews_per_month
# 169       Valor Absoluto               accommodates
# 170           Cuadratica               accommodates
# 171          Exponencial          reviews_per_month
# 172          Logarítmica               accommodates
# 173           Tangencial          reviews_per_month
# 174           Tangencial               accommodates
# 175          Exponencial               accommodates
# 176           Tangencial          reviews_per_month
# 177             Senoidal  host_total_listings_count
# 178           Tangencial          reviews_per_month
# 179           Tangencial          reviews_per_month
# 180           Tangencial       host_acceptance_rate
# 181           Tangencial          reviews_per_month
# 182           Tangencial  host_total_listings_count
# 183           Tangencial  host_total_listings_count
# 184           Tangencial         host_response_rate
# 185           Tangencial         host_response_rate
# 186             Senoidal       host_acceptance_rate
# 187   Polinomial Inversa          reviews_per_month
# 188          Exponencial               accommodates
# 189           Tangencial         host_response_rate
# 190             Senoidal               accommodates
# 191           Tangencial  host_total_listings_count
# 192           Tangencial               accommodates
# 193           Tangencial               accommodates
# 194      Lineal Producto               accommodates
# 195              Inversa               accommodates
# 196  Cociente Polinómico       host_acceptance_rate
# 197      Lineal Producto       host_acceptance_rate
# 198              Inversa       host_acceptance_rate
# 199  Cociente Polinómico       host_acceptance_rate
# 200              Inversa          reviews_per_month
# 201      Lineal Producto          reviews_per_month
# 202  Cociente Polinómico               accommodates
# 203              Inversa       host_acceptance_rate
# 204      Lineal Producto       host_acceptance_rate
# 205  Cociente Polinómico  host_total_listings_count
# 206  Cociente Polinómico         host_response_rate
# 207      Lineal Producto         host_response_rate
# 208              Inversa         host_response_rate
# 209  Cociente Polinómico               accommodates
# 210  Cociente Polinómico               accommodates
# 211      Lineal Producto         host_response_rate
# 212              Inversa         host_response_rate
# 213              Inversa       host_acceptance_rate
# 214      Lineal Producto       host_acceptance_rate
# 215      Lineal Producto          reviews_per_month
# 216              Inversa          reviews_per_month
# 217   Cuadrática Inversa         host_response_rate
# 218   Cuadrática Inversa  host_total_listings_count
# 219   Cuadrática Inversa       host_acceptance_rate
# 220   Cuadrática Inversa          reviews_per_month
# 221   Cuadrática Inversa               accommodates
# 222              Inversa  host_total_listings_count
# 223      Lineal Producto  host_total_listings_count
# 224              Inversa               accommodates
# 225      Lineal Producto               accommodates
# 226  Cociente Polinómico       host_acceptance_rate
# 227      Lineal Producto               accommodates
# 228              Inversa               accommodates
# 229              Inversa               accommodates
# 230      Lineal Producto               accommodates
# 231              Inversa         host_response_rate
# 232      Lineal Producto         host_response_rate
# 233      Lineal Producto          reviews_per_month
# 234              Inversa          reviews_per_month
# 235              Inversa          reviews_per_month
# 236      Lineal Producto          reviews_per_month
# 237      Lineal Producto       host_acceptance_rate
# 238              Inversa       host_acceptance_rate
# 239      Lineal Producto  host_total_listings_count
# 240              Inversa  host_total_listings_count
# 241              Inversa          reviews_per_month
# 242      Lineal Producto          reviews_per_month
# 243   Cuadrática Inversa               accommodates
# 244   Cuadrática Inversa       host_acceptance_rate
# 245   Cuadrática Inversa          reviews_per_month
# 246   Cuadrática Inversa         host_response_rate
# 247      Lineal Producto  host_total_listings_count
# 248              Inversa  host_total_listings_count
# 249              Inversa  host_total_listings_count
# 250      Lineal Producto  host_total_listings_count
# 251      Lineal Producto  host_total_listings_count
# 252              Inversa  host_total_listings_count
# 253   Cuadrática Inversa         host_response_rate
# 254   Cuadrática Inversa       host_acceptance_rate
# 255   Cuadrática Inversa          reviews_per_month
# 256   Cuadrática Inversa  host_total_listings_count
# 257   Cuadrática Inversa         host_response_rate
# 258   Cuadrática Inversa       host_acceptance_rate
# 259   Cuadrática Inversa               accommodates
# 260   Cuadrática Inversa  host_total_listings_count
# 261          Exponencial       host_acceptance_rate
# 262          Exponencial       host_acceptance_rate
# 263          Exponencial       host_acceptance_rate
# 264          Exponencial       host_acceptance_rate
# 265          Exponencial       host_acceptance_rate
# 266          Exponencial         host_response_rate
# 267          Exponencial         host_response_rate
# 268          Exponencial         host_response_rate
# 269          Exponencial         host_response_rate
# 270          Exponencial         host_response_rate
# 271          Exponencial  host_total_listings_count
# 272          Exponencial  host_total_listings_count
# 273          Exponencial  host_total_listings_count
# 274          Exponencial  host_total_listings_count
# 275          Exponencial  host_total_listings_count
#
#                     Variable 2            R²
# 1         host_acceptance_rate  8.831528e-01
# 2         host_acceptance_rate  8.831528e-01
# 3         host_acceptance_rate  8.831528e-01
# 4         host_acceptance_rate  8.831528e-01
# 5           host_response_rate  4.207775e-01
# 6         host_acceptance_rate  4.083452e-01
# 7           host_response_rate  4.080631e-01
# 8         host_acceptance_rate  4.029678e-01
# 9         host_acceptance_rate  4.029678e-01
# 10          host_response_rate  4.029678e-01
# 11          host_response_rate  4.029678e-01
# 12          host_response_rate  4.029678e-01
# 13          host_response_rate  4.029678e-01
# 14          host_response_rate  4.029678e-01
# 15          host_response_rate  4.029678e-01
# 16          host_response_rate  3.278174e-01
# 17        host_acceptance_rate  3.241040e-01
# 18        host_acceptance_rate  3.136035e-01
# 19          host_response_rate  3.051477e-01
# 20          host_response_rate  3.051477e-01
# 21        host_acceptance_rate  2.937780e-01
# 22        host_acceptance_rate  2.937780e-01
# 23        host_acceptance_rate  1.093059e-01
# 24                       price  9.392101e-02
# 25                       price  8.715369e-02
# 26                       price  8.715369e-02
# 27                       price  8.705682e-02
# 28                       price  8.699791e-02
# 29                       price  8.699791e-02
# 30          host_response_rate  8.174116e-02
# 31          host_response_rate  8.024877e-02
# 32           reviews_per_month  7.669788e-02
# 33                       price  6.839987e-02
# 34        host_acceptance_rate  5.343284e-02
# 35        host_acceptance_rate  5.325141e-02
# 36        host_acceptance_rate  5.158799e-02
# 37        host_acceptance_rate  5.158799e-02
# 38           reviews_per_month  5.158799e-02
# 39           reviews_per_month  5.158799e-02
# 40           reviews_per_month  5.026752e-02
# 41          host_response_rate  4.905886e-02
# 42          host_response_rate  4.722811e-02
# 43          host_response_rate  4.703720e-02
# 44          host_response_rate  4.703705e-02
# 45          host_response_rate  4.703705e-02
# 46           reviews_per_month  4.703705e-02
# 47           reviews_per_month  4.703705e-02
# 48        host_acceptance_rate  4.671075e-02
# 49                       price  4.325172e-02
# 50        host_acceptance_rate  4.296066e-02
# 51                       price  4.195074e-02
# 52                       price  4.195074e-02
# 53        host_acceptance_rate  4.013611e-02
# 54          host_response_rate  3.149468e-02
# 55           reviews_per_month  3.103639e-02
# 56        host_acceptance_rate  3.049108e-02
# 57           reviews_per_month  2.955129e-02
# 58                       price  2.916458e-02
# 59                       price  2.667813e-02
# 60          host_response_rate  2.575022e-02
# 61          host_response_rate  2.542535e-02
# 62                       price  2.079264e-02
# 63                       price  2.069558e-02
# 64                       price  2.069558e-02
# 65                       price  2.063536e-02
# 66   host_total_listings_count  2.044560e-02
# 67   host_total_listings_count  2.044560e-02
# 68          host_response_rate  2.044560e-02
# 69          host_response_rate  2.044560e-02
# 70   host_total_listings_count  2.031085e-02
# 71   host_total_listings_count  1.999636e-02
# 72   host_total_listings_count  1.984015e-02
# 73   host_total_listings_count  1.914095e-02
# 74   host_total_listings_count  1.914095e-02
# 75           reviews_per_month  1.747065e-02
# 76   host_total_listings_count  1.461918e-02
# 77   host_total_listings_count  1.367787e-02
# 78                       price  1.173043e-02
# 79                accommodates  1.152491e-02
# 80          host_response_rate  1.118659e-02
# 81        host_acceptance_rate  1.095915e-02
# 82                       price  9.949938e-03
# 83           reviews_per_month  9.483645e-03
# 84                       price  7.417647e-03
# 85                accommodates  7.282863e-03
# 86                       price  7.261132e-03
# 87           reviews_per_month  7.182507e-03
# 88   host_total_listings_count  7.037366e-03
# 89                       price  6.470446e-03
# 90   host_total_listings_count  6.373074e-03
# 91   host_total_listings_count  6.127302e-03
# 92   host_total_listings_count  6.127302e-03
# 93                accommodates  6.127302e-03
# 94                accommodates  6.127302e-03
# 95   host_total_listings_count  6.126527e-03
# 96                       price  5.888713e-03
# 97        host_acceptance_rate  5.541680e-03
# 98                       price  5.029491e-03
# 99                       price  5.029491e-03
# 100  host_total_listings_count  5.025994e-03
# 101  host_total_listings_count  5.025994e-03
# 102       host_acceptance_rate  5.025994e-03
# 103       host_acceptance_rate  5.025994e-03
# 104          reviews_per_month  4.906955e-03
# 105  host_total_listings_count  4.654730e-03
# 106         host_response_rate  4.401958e-03
# 107  host_total_listings_count  3.917082e-03
# 108  host_total_listings_count  3.794079e-03
# 109                      price  3.350969e-03
# 110                      price  3.350969e-03
# 111          reviews_per_month  3.010925e-03
# 112                      price  2.966273e-03
# 113                      price  2.788319e-03
# 114       host_acceptance_rate  2.436925e-03
# 115               accommodates  2.385544e-03
# 116  host_total_listings_count  2.334130e-03
# 117       host_acceptance_rate  2.323532e-03
# 118  host_total_listings_count  2.286097e-03
# 119  host_total_listings_count  2.250923e-03
# 120                      price  2.225900e-03
# 121         host_response_rate  2.178584e-03
# 122  host_total_listings_count  2.131881e-03
# 123          reviews_per_month  1.941511e-03
# 124          reviews_per_month  1.860022e-03
# 125          reviews_per_month  1.733526e-03
# 126          reviews_per_month  1.733526e-03
# 127  host_total_listings_count  1.733526e-03
# 128  host_total_listings_count  1.733526e-03
# 129       host_acceptance_rate  1.733166e-03
# 130  host_total_listings_count  1.733025e-03
# 131          reviews_per_month  1.674817e-03
# 132         host_response_rate  1.670115e-03
# 133                      price  1.337803e-03
# 134                      price  1.331546e-03
# 135  host_total_listings_count  1.325345e-03
# 136  host_total_listings_count  1.317556e-03
# 137       host_acceptance_rate  1.144073e-03
# 138               accommodates  1.121297e-03
# 139               accommodates  1.121297e-03
# 140       host_acceptance_rate  1.121297e-03
# 141       host_acceptance_rate  1.121297e-03
# 142          reviews_per_month  1.073580e-03
# 143         host_response_rate  1.045197e-03
# 144          reviews_per_month  1.019089e-03
# 145               accommodates  8.425218e-04
# 146               accommodates  8.151451e-04
# 147               accommodates  7.703402e-04
# 148               accommodates  7.589885e-04
# 149         host_response_rate  6.907608e-04
# 150  host_total_listings_count  6.804121e-04
# 151                      price  6.623598e-04
# 152                      price  5.847792e-04
# 153         host_response_rate  5.666801e-04
# 154         host_response_rate  5.666801e-04
# 155               accommodates  5.666801e-04
# 156               accommodates  5.666801e-04
# 157                      price  5.266788e-04
# 158               accommodates  4.583167e-04
# 159               accommodates  4.579743e-04
# 160               accommodates  3.683523e-04
# 161                      price  3.627430e-04
# 162               accommodates  3.104839e-04
# 163          reviews_per_month  3.099094e-04
# 164         host_response_rate  3.094438e-04
# 165  host_total_listings_count  2.274204e-04
# 166               accommodates  1.930291e-04
# 167               accommodates  1.760142e-04
# 168               accommodates  1.760142e-04
# 169          reviews_per_month  1.760142e-04
# 170          reviews_per_month  1.760142e-04
# 171               accommodates  1.757899e-04
# 172       host_acceptance_rate  1.664594e-04
# 173       host_acceptance_rate  1.570961e-04
# 174         host_response_rate  1.352233e-04
# 175          reviews_per_month  1.351937e-04
# 176         host_response_rate  1.158193e-04
# 177          reviews_per_month  1.023471e-04
# 178  host_total_listings_count  6.828434e-05
# 179               accommodates  6.703929e-05
# 180               accommodates  6.580899e-05
# 181                      price  3.863988e-05
# 182               accommodates  2.869378e-05
# 183          reviews_per_month  2.686542e-05
# 184               accommodates  2.369412e-05
# 185       host_acceptance_rate  2.272284e-05
# 186               accommodates  1.273370e-05
# 187               accommodates  7.626909e-06
# 188         host_response_rate  6.808621e-06
# 189          reviews_per_month  3.202701e-06
# 190       host_acceptance_rate  1.594007e-06
# 191                      price  3.536688e-07
# 192          reviews_per_month  4.813409e-08
# 193       host_acceptance_rate  3.072599e-09
# 194  host_total_listings_count -5.105878e-05
# 195  host_total_listings_count -5.105878e-05
# 196  host_total_listings_count -3.983721e-03
# 197  host_total_listings_count -4.591597e-03
# 198  host_total_listings_count -4.591597e-03
# 199                      price -1.905355e-02
# 200  host_total_listings_count -3.110355e-02
# 201  host_total_listings_count -3.110355e-02
# 202          reviews_per_month -5.939189e-02
# 203          reviews_per_month -9.640647e-02
# 204          reviews_per_month -9.640647e-02
# 205                      price -9.738431e-02
# 206               accommodates -1.082765e-01
# 207          reviews_per_month -1.121250e-01
# 208          reviews_per_month -1.121250e-01
# 209         host_response_rate -1.154796e-01
# 210       host_acceptance_rate -1.312360e-01
# 211                      price -1.403747e-01
# 212                      price -1.403747e-01
# 213                      price -1.633946e-01
# 214                      price -1.633946e-01
# 215                      price -1.695549e-01
# 216                      price -1.695549e-01
# 217                      price -2.663364e-01
# 218                      price -2.663364e-01
# 219                      price -2.663364e-01
# 220                      price -2.663364e-01
# 221                      price -2.663364e-01
# 222                      price -2.754431e-01
# 223                      price -2.754431e-01
# 224          reviews_per_month -2.815310e-01
# 225          reviews_per_month -2.815310e-01
# 226               accommodates -2.976200e-01
# 227         host_response_rate -6.203286e-01
# 228         host_response_rate -6.203286e-01
# 229       host_acceptance_rate -7.179623e-01
# 230       host_acceptance_rate -7.179623e-01
# 231               accommodates -9.131654e-01
# 232               accommodates -9.131654e-01
# 233         host_response_rate -9.365991e-01
# 234         host_response_rate -9.365991e-01
# 235       host_acceptance_rate -9.404679e-01
# 236       host_acceptance_rate -9.404679e-01
# 237               accommodates -9.957876e-01
# 238               accommodates -9.957876e-01
# 239          reviews_per_month -1.342887e+00
# 240          reviews_per_month -1.342887e+00
# 241               accommodates -1.634903e+00
# 242               accommodates -1.634903e+00
# 243  host_total_listings_count -1.830738e+00
# 244  host_total_listings_count -1.830738e+00
# 245  host_total_listings_count -1.830738e+00
# 246  host_total_listings_count -1.830738e+00
# 247         host_response_rate -2.880983e+00
# 248         host_response_rate -2.880983e+00
# 249       host_acceptance_rate -3.039926e+00
# 250       host_acceptance_rate -3.039926e+00
# 251               accommodates -3.672042e+00
# 252               accommodates -3.672042e+00
# 253               accommodates -1.623952e+03
# 254               accommodates -1.623952e+03
# 255               accommodates -1.623952e+03
# 256               accommodates -1.623952e+03
# 257          reviews_per_month -9.168217e+03
# 258          reviews_per_month -9.168217e+03
# 259          reviews_per_month -9.168217e+03
# 260          reviews_per_month -9.168217e+03
# 261                      price -1.156065e+41
# 262  host_total_listings_count -5.787788e+43
# 263         host_response_rate -7.654977e+43
# 264               accommodates -3.574916e+46
# 265          reviews_per_month -1.886653e+47
# 266                      price -1.533518e+52
# 267  host_total_listings_count -7.677485e+54
# 268       host_acceptance_rate -1.211568e+55
# 269               accommodates -4.742116e+57
# 270          reviews_per_month -2.502639e+58
# 271               accommodates          -inf
# 272       host_acceptance_rate          -inf
# 273                      price          -inf
# 274         host_response_rate          -inf
# 275          reviews_per_month          -inf
